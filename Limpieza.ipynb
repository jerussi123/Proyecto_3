# %% [markdown]
# # Limpieza proyecto 3

# %% [markdown]
# #### Primero se trae la data del csv

# %%
import pandas as pd

data = pd.read_csv("datos_norte_santander.csv")
data.head()
# Out:
#    periodo estu_tipodocumento  estu_consecutivo cole_area_ubicacion  \
# 0    20112                 TI  SB11201120186494              URBANO
# 1    20194                 TI  SB11201940250932              URBANO
# 2    20194                 TI  SB11201940250932              URBANO
# 3    20112                 TI  SB11201120193635               RURAL
# 4    20102                 TI  SB11201020198930              URBANO
#
#   cole_bilingue cole_calendario      cole_caracter  \
# 0             N               A  TÉCNICO/ACADÉMICO
# 1           NaN               A  TÉCNICO/ACADÉMICO
# 2           NaN               A  TÉCNICO/ACADÉMICO
# 3             N               A          ACADÉMICO
# 4             N               A  TÉCNICO/ACADÉMICO
#
#    cole_cod_dane_establecimiento  cole_cod_dane_sede  \
# 0                   1.540010e+11        154001009017
# 1                   1.540010e+11        154001002136
# 2                   1.540010e+11        154001002136
# 3                   2.540510e+11        254051000821
# 4                   1.548740e+11        154874000806
#
#    cole_cod_depto_ubicacion  ...  fami_tienecomputador  fami_tieneinternet  \
# 0                        54  ...                    No                  No
# 1                        54  ...                    No                  Si
# 2                        54  ...                    No                  Si
# 3                        54  ...                    No                  No
# 4                        54  ...                    No                  No
#
#   fami_tienelavadora desemp_ingles punt_ingles punt_matematicas  \
# 0                 Si            A-       41.00            31.00
# 1                 Si            A-       32.00            45.00
# 2                 Si            A-       32.00            45.00
# 3                 No            A-       34.00            39.00
# 4                 No            A-       38.53            50.82
#
#   punt_sociales_ciudadanas punt_c_naturales punt_lectura_critica punt_global
# 0                      NaN              NaN                  NaN         NaN
# 1                     42.0             42.0                 49.0       218.0
# 2                     42.0             42.0                 49.0       218.0
# 3                      NaN              NaN                  NaN         NaN
# 4                      NaN              NaN                  NaN         NaN
#
# [5 rows x 51 columns]

# %% [markdown]
# #### Ahora revisamos los duplicados

# %%
duplicates = len(data[data.duplicated()])
print(f'Number of Duplicate Entries: {duplicates}')
# Out:
# Number of Duplicate Entries: 35924

# %%
data[data.duplicated()]
# Out:
#         periodo estu_tipodocumento  estu_consecutivo cole_area_ubicacion  \
# 2         20194                 TI  SB11201940250932              URBANO
# 6         20194                 TI  SB11201940475810              URBANO
# 22        20194                 TI  SB11201940484666              URBANO
# 26        20194                 CC  SB11201940516631              URBANO
# 28        20194                 CC  SB11201940286383              URBANO
# ...         ...                ...               ...                 ...
# 195829    20194                 TI  SB11201940387027              URBANO
# 195842    20194                 TI  SB11201940338767              URBANO
# 195846    20194                 TI  SB11201940481899               RURAL
# 195849    20194                 TI  SB11201940350219              URBANO
# 195851    20194                 TI  SB11201940550697              URBANO
#
#        cole_bilingue cole_calendario      cole_caracter  \
# 2                NaN               A  TÉCNICO/ACADÉMICO
# 6                  N               A          ACADÉMICO
# 22                 N               A  TÉCNICO/ACADÉMICO
# 26                 N               A  TÉCNICO/ACADÉMICO
# 28                 N               A          ACADÉMICO
# ...              ...             ...                ...
# 195829             N               A  TÉCNICO/ACADÉMICO
# 195842             N               A          ACADÉMICO
# 195846             N               A  TÉCNICO/ACADÉMICO
# 195849             N               A  TÉCNICO/ACADÉMICO
# 195851             N               A          ACADÉMICO
#
#         cole_cod_dane_establecimiento  cole_cod_dane_sede  \
# 2                        1.540010e+11        154001002136
# 6                        1.548740e+11        154874000016
# 22                       2.548740e+11        254874000363
# 26                       2.548740e+11        254874000363
# 28                       3.544980e+11        354498002559
# ...                               ...                 ...
# 195829                   1.548740e+11        154874000041
# 195842                   3.540010e+11        354001006530
# 195846                   2.548100e+11        254810002061
# 195849                   1.540010e+11        154001001628
# 195851                   3.540010e+11        354001012211
#
#         cole_cod_depto_ubicacion  ...  fami_tienecomputador  \
# 2                             54  ...                    No
# 6                             54  ...                    No
# 22                            54  ...                    No
# 26                            54  ...                    Si
# 28                            54  ...                    No
# ...                          ...  ...                   ...
# 195829                        54  ...                    Si
# 195842                        54  ...                    Si
# 195846                        54  ...                    No
# 195849                        54  ...                    Si
# 195851                        54  ...                    No
#
#         fami_tieneinternet fami_tienelavadora desemp_ingles punt_ingles  \
# 2                       Si                 Si            A-        32.0
# 6                       No                 No            A-        38.0
# 22                      No                 Si            A1        49.0
# 26                      Si                 Si            A1        52.0
# 28                      Si                 Si            A-        47.0
# ...                    ...                ...           ...         ...
# 195829                  Si                 No            A-        28.0
# 195842                  Si                 Si            A2        64.0
# 195846                  No                 Si            A-        36.0
# 195849                  Si                 No            B+        83.0
# 195851                  Si                 Si            A1        52.0
#
#        punt_matematicas punt_sociales_ciudadanas punt_c_naturales  \
# 2                  45.0                     42.0             42.0
# 6                  21.0                     32.0             29.0
# 22                 52.0                     51.0             52.0
# 26                 46.0                     41.0             43.0
# 28                 49.0                     47.0             45.0
# ...                 ...                      ...              ...
# 195829             42.0                     33.0             45.0
# 195842             58.0                     47.0             62.0
# 195846             61.0                     61.0             56.0
# 195849             79.0                     81.0             72.0
# 195851             45.0                     42.0             55.0
#
#        punt_lectura_critica punt_global
# 2                      49.0       218.0
# 6                      33.0       147.0
# 22                     63.0       270.0
# 26                     55.0       233.0
# 28                     52.0       241.0
# ...                     ...         ...
# 195829                 37.0       192.0
# 195842                 63.0       290.0
# 195846                 65.0       294.0
# 195849                 71.0       382.0
# 195851                 52.0       244.0
#
# [35924 rows x 51 columns]
