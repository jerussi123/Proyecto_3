# %% [markdown]
# # Limpieza proyecto 3

# %% [markdown]
# #### Primero se trae la data del csv

# %%
import pandas as pd

data_completa = pd.read_csv("datos_norte_santander.csv")
data_completa.head()
# Out:
#    periodo estu_tipodocumento  estu_consecutivo cole_area_ubicacion  \
# 0    20112                 TI  SB11201120186494              URBANO
# 1    20194                 TI  SB11201940250932              URBANO
# 2    20194                 TI  SB11201940250932              URBANO
# 3    20112                 TI  SB11201120193635               RURAL
# 4    20102                 TI  SB11201020198930              URBANO
#
#   cole_bilingue cole_calendario      cole_caracter  \
# 0             N               A  TÉCNICO/ACADÉMICO
# 1           NaN               A  TÉCNICO/ACADÉMICO
# 2           NaN               A  TÉCNICO/ACADÉMICO
# 3             N               A          ACADÉMICO
# 4             N               A  TÉCNICO/ACADÉMICO
#
#    cole_cod_dane_establecimiento  cole_cod_dane_sede  \
# 0                   1.540010e+11        154001009017
# 1                   1.540010e+11        154001002136
# 2                   1.540010e+11        154001002136
# 3                   2.540510e+11        254051000821
# 4                   1.548740e+11        154874000806
#
#    cole_cod_depto_ubicacion  ...  fami_tienecomputador  fami_tieneinternet  \
# 0                        54  ...                    No                  No
# 1                        54  ...                    No                  Si
# 2                        54  ...                    No                  Si
# 3                        54  ...                    No                  No
# 4                        54  ...                    No                  No
#
#   fami_tienelavadora desemp_ingles punt_ingles punt_matematicas  \
# 0                 Si            A-       41.00            31.00
# 1                 Si            A-       32.00            45.00
# 2                 Si            A-       32.00            45.00
# 3                 No            A-       34.00            39.00
# 4                 No            A-       38.53            50.82
#
#   punt_sociales_ciudadanas punt_c_naturales punt_lectura_critica punt_global
# 0                      NaN              NaN                  NaN         NaN
# 1                     42.0             42.0                 49.0       218.0
# 2                     42.0             42.0                 49.0       218.0
# 3                      NaN              NaN                  NaN         NaN
# 4                      NaN              NaN                  NaN         NaN
#
# [5 rows x 51 columns]

# %% [markdown]
# #### Primero sacaremos algunas columnas que no nos van a aportar en nada

# %%
data = data_completa.drop(['estu_tipodocumento', 'estu_consecutivo', 'cole_cod_dane_establecimiento', 'cole_cod_dane_sede', 'cole_cod_depto_ubicacion', 
                  'cole_codigo_icfes', 'cole_depto_ubicacion', 'cole_nombre_establecimiento', 'cole_nombre_sede', 'cole_sede_principal', 
                  'estu_cod_depto_presentacion', 'estu_cod_reside_depto', 'estu_depto_presentacion', 'estu_depto_reside', 
                  'estu_estadoinvestigacion', 'estu_estudiante', 'estu_nacionalidad', 'estu_pais_reside', 'estu_privado_libertad'], axis=1)
data
# Out:
#         periodo cole_area_ubicacion cole_bilingue cole_calendario  \
# 0         20112              URBANO             N               A
# 1         20194              URBANO           NaN               A
# 2         20194              URBANO           NaN               A
# 3         20112               RURAL             N               A
# 4         20102              URBANO             N               A
# ...         ...                 ...           ...             ...
# 195852    20172              URBANO             N               A
# 195853    20112              URBANO             N               A
# 195854    20142              URBANO             N               A
# 195855    20142              URBANO             N               A
# 195856    20122              URBANO             N               A
#
#             cole_caracter  cole_cod_mcpio_ubicacion cole_genero cole_jornada  \
# 0       TÉCNICO/ACADÉMICO                     54001       MIXTO        TARDE
# 1       TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 2       TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 3               ACADÉMICO                     54051       MIXTO     COMPLETA
# 4       TÉCNICO/ACADÉMICO                     54874       MIXTO       MAÑANA
# ...                   ...                       ...         ...          ...
# 195852  TÉCNICO/ACADÉMICO                     54405       MIXTO       MAÑANA
# 195853  TÉCNICO/ACADÉMICO                     54518       MIXTO     COMPLETA
# 195854  TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 195855            TÉCNICO                     54800       MIXTO       MAÑANA
# 195856          ACADÉMICO                     54001       MIXTO     COMPLETA
#
#        cole_mcpio_ubicacion cole_naturaleza  ...  fami_tienecomputador  \
# 0                    CÚCUTA         OFICIAL  ...                    No
# 1                    CÚCUTA         OFICIAL  ...                    No
# 2                    CÚCUTA         OFICIAL  ...                    No
# 3                 ARBOLEDAS         OFICIAL  ...                    No
# 4         VILLA DEL ROSARIO         OFICIAL  ...                    No
# ...                     ...             ...  ...                   ...
# 195852           LOS PATIOS         OFICIAL  ...                    No
# 195853             PAMPLONA         OFICIAL  ...                    No
# 195854               CUCUTA         OFICIAL  ...                    No
# 195855              TEORAMA         OFICIAL  ...                    No
# 195856               CÚCUTA      NO OFICIAL  ...                    Si
#
#         fami_tieneinternet fami_tienelavadora desemp_ingles punt_ingles  \
# 0                       No                 Si            A-       41.00
# 1                       Si                 Si            A-       32.00
# 2                       Si                 Si            A-       32.00
# 3                       No                 No            A-       34.00
# 4                       No                 No            A-       38.53
# ...                    ...                ...           ...         ...
# 195852                  No                 Si            A1       51.00
# 195853                  No                 Si            A2       56.00
# 195854                  No                 No            A-       47.00
# 195855                  No                 No            A-       41.00
# 195856                  Si                 Si            B1       77.00
#
#        punt_matematicas punt_sociales_ciudadanas punt_c_naturales  \
# 0                 31.00                      NaN              NaN
# 1                 45.00                     42.0             42.0
# 2                 45.00                     42.0             42.0
# 3                 39.00                      NaN              NaN
# 4                 50.82                      NaN              NaN
# ...                 ...                      ...              ...
# 195852            50.00                     60.0             55.0
# 195853            85.00                      NaN              NaN
# 195854            33.00                     44.0             40.0
# 195855            47.00                     49.0             49.0
# 195856            97.00                      NaN              NaN
#
#        punt_lectura_critica punt_global
# 0                       NaN         NaN
# 1                      49.0       218.0
# 2                      49.0       218.0
# 3                       NaN         NaN
# 4                       NaN         NaN
# ...                     ...         ...
# 195852                 50.0       268.0
# 195853                  NaN         NaN
# 195854                 29.0       187.0
# 195855                 52.0       243.0
# 195856                  NaN         NaN
#
# [195857 rows x 32 columns]

# %% [markdown]
# #### Ahora revisamos los duplicados

# %%
duplicates = len(data[data.duplicated()])
print(f'Number of Duplicate Entries: {duplicates}')
data[data.duplicated()]
# Out:
# Number of Duplicate Entries: 35924
#         periodo cole_area_ubicacion cole_bilingue cole_calendario  \
# 2         20194              URBANO           NaN               A
# 6         20194              URBANO             N               A
# 22        20194              URBANO             N               A
# 26        20194              URBANO             N               A
# 28        20194              URBANO             N               A
# ...         ...                 ...           ...             ...
# 195829    20194              URBANO             N               A
# 195842    20194              URBANO             N               A
# 195846    20194               RURAL             N               A
# 195849    20194              URBANO             N               A
# 195851    20194              URBANO             N               A
#
#             cole_caracter  cole_cod_mcpio_ubicacion cole_genero cole_jornada  \
# 2       TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 6               ACADÉMICO                     54874       MIXTO        NOCHE
# 22      TÉCNICO/ACADÉMICO                     54405       MIXTO       MAÑANA
# 26      TÉCNICO/ACADÉMICO                     54405       MIXTO        TARDE
# 28              ACADÉMICO                     54498       MIXTO        NOCHE
# ...                   ...                       ...         ...          ...
# 195829  TÉCNICO/ACADÉMICO                     54874       MIXTO       MAÑANA
# 195842          ACADÉMICO                     54001       MIXTO       MAÑANA
# 195846  TÉCNICO/ACADÉMICO                     54810    FEMENINO       MAÑANA
# 195849  TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 195851          ACADÉMICO                     54001       MIXTO       MAÑANA
#
#        cole_mcpio_ubicacion cole_naturaleza  ...  fami_tienecomputador  \
# 2                    CÚCUTA         OFICIAL  ...                    No
# 6         VILLA DEL ROSARIO         OFICIAL  ...                    No
# 22               LOS PATIOS         OFICIAL  ...                    No
# 26               LOS PATIOS         OFICIAL  ...                    Si
# 28                    OCAÑA      NO OFICIAL  ...                    No
# ...                     ...             ...  ...                   ...
# 195829    VILLA DEL ROSARIO         OFICIAL  ...                    Si
# 195842               CÚCUTA      NO OFICIAL  ...                    Si
# 195846                 TIBÚ         OFICIAL  ...                    No
# 195849               CÚCUTA         OFICIAL  ...                    Si
# 195851               CÚCUTA      NO OFICIAL  ...                    No
#
#         fami_tieneinternet fami_tienelavadora desemp_ingles punt_ingles  \
# 2                       Si                 Si            A-        32.0
# 6                       No                 No            A-        38.0
# 22                      No                 Si            A1        49.0
# 26                      Si                 Si            A1        52.0
# 28                      Si                 Si            A-        47.0
# ...                    ...                ...           ...         ...
# 195829                  Si                 No            A-        28.0
# 195842                  Si                 Si            A2        64.0
# 195846                  No                 Si            A-        36.0
# 195849                  Si                 No            B+        83.0
# 195851                  Si                 Si            A1        52.0
#
#        punt_matematicas punt_sociales_ciudadanas punt_c_naturales  \
# 2                  45.0                     42.0             42.0
# 6                  21.0                     32.0             29.0
# 22                 52.0                     51.0             52.0
# 26                 46.0                     41.0             43.0
# 28                 49.0                     47.0             45.0
# ...                 ...                      ...              ...
# 195829             42.0                     33.0             45.0
# 195842             58.0                     47.0             62.0
# 195846             61.0                     61.0             56.0
# 195849             79.0                     81.0             72.0
# 195851             45.0                     42.0             55.0
#
#        punt_lectura_critica punt_global
# 2                      49.0       218.0
# 6                      33.0       147.0
# 22                     63.0       270.0
# 26                     55.0       233.0
# 28                     52.0       241.0
# ...                     ...         ...
# 195829                 37.0       192.0
# 195842                 63.0       290.0
# 195846                 65.0       294.0
# 195849                 71.0       382.0
# 195851                 52.0       244.0
#
# [35924 rows x 32 columns]

# %% [markdown]
# #### Ahora quitamos los duplicados

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#         periodo cole_area_ubicacion cole_bilingue cole_calendario  \
# 0         20112              URBANO             N               A
# 1         20194              URBANO           NaN               A
# 3         20112               RURAL             N               A
# 4         20102              URBANO             N               A
# 5         20194              URBANO             N               A
# ...         ...                 ...           ...             ...
# 195852    20172              URBANO             N               A
# 195853    20112              URBANO             N               A
# 195854    20142              URBANO             N               A
# 195855    20142              URBANO             N               A
# 195856    20122              URBANO             N               A
#
#             cole_caracter  cole_cod_mcpio_ubicacion cole_genero cole_jornada  \
# 0       TÉCNICO/ACADÉMICO                     54001       MIXTO        TARDE
# 1       TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 3               ACADÉMICO                     54051       MIXTO     COMPLETA
# 4       TÉCNICO/ACADÉMICO                     54874       MIXTO       MAÑANA
# 5               ACADÉMICO                     54874       MIXTO        NOCHE
# ...                   ...                       ...         ...          ...
# 195852  TÉCNICO/ACADÉMICO                     54405       MIXTO       MAÑANA
# 195853  TÉCNICO/ACADÉMICO                     54518       MIXTO     COMPLETA
# 195854  TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 195855            TÉCNICO                     54800       MIXTO       MAÑANA
# 195856          ACADÉMICO                     54001       MIXTO     COMPLETA
#
#        cole_mcpio_ubicacion cole_naturaleza  ...  fami_tienecomputador  \
# 0                    CÚCUTA         OFICIAL  ...                    No
# 1                    CÚCUTA         OFICIAL  ...                    No
# 3                 ARBOLEDAS         OFICIAL  ...                    No
# 4         VILLA DEL ROSARIO         OFICIAL  ...                    No
# 5         VILLA DEL ROSARIO         OFICIAL  ...                    No
# ...                     ...             ...  ...                   ...
# 195852           LOS PATIOS         OFICIAL  ...                    No
# 195853             PAMPLONA         OFICIAL  ...                    No
# 195854               CUCUTA         OFICIAL  ...                    No
# 195855              TEORAMA         OFICIAL  ...                    No
# 195856               CÚCUTA      NO OFICIAL  ...                    Si
#
#         fami_tieneinternet fami_tienelavadora desemp_ingles punt_ingles  \
# 0                       No                 Si            A-       41.00
# 1                       Si                 Si            A-       32.00
# 3                       No                 No            A-       34.00
# 4                       No                 No            A-       38.53
# 5                       No                 No            A-       38.00
# ...                    ...                ...           ...         ...
# 195852                  No                 Si            A1       51.00
# 195853                  No                 Si            A2       56.00
# 195854                  No                 No            A-       47.00
# 195855                  No                 No            A-       41.00
# 195856                  Si                 Si            B1       77.00
#
#        punt_matematicas punt_sociales_ciudadanas punt_c_naturales  \
# 0                 31.00                      NaN              NaN
# 1                 45.00                     42.0             42.0
# 3                 39.00                      NaN              NaN
# 4                 50.82                      NaN              NaN
# 5                 21.00                     32.0             29.0
# ...                 ...                      ...              ...
# 195852            50.00                     60.0             55.0
# 195853            85.00                      NaN              NaN
# 195854            33.00                     44.0             40.0
# 195855            47.00                     49.0             49.0
# 195856            97.00                      NaN              NaN
#
#        punt_lectura_critica punt_global
# 0                       NaN         NaN
# 1                      49.0       218.0
# 3                       NaN         NaN
# 4                       NaN         NaN
# 5                      33.0       147.0
# ...                     ...         ...
# 195852                 50.0       268.0
# 195853                  NaN         NaN
# 195854                 29.0       187.0
# 195855                 52.0       243.0
# 195856                  NaN         NaN
#
# [159933 rows x 32 columns]

# %% [markdown]
# #### Revisamos los valores nulos en la variable de salida puntajes globales "punt_global" y eliminamos las filas que tengan NaN o vacio

# %%
count_nan = data['punt_global'].isnull().sum()
count_nan
# Out:
# 64830

# %%
data = data[data['punt_global'].notna()]
data
# Out:
#         periodo cole_area_ubicacion cole_bilingue cole_calendario  \
# 1         20194              URBANO           NaN               A
# 5         20194              URBANO             N               A
# 7         20172              URBANO             N               A
# 8         20162               RURAL             N               A
# 10        20172              URBANO             N               A
# ...         ...                 ...           ...             ...
# 195848    20194              URBANO             N               A
# 195850    20194              URBANO             N               A
# 195852    20172              URBANO             N               A
# 195854    20142              URBANO             N               A
# 195855    20142              URBANO             N               A
#
#             cole_caracter  cole_cod_mcpio_ubicacion cole_genero cole_jornada  \
# 1       TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 5               ACADÉMICO                     54874       MIXTO        NOCHE
# 7               ACADÉMICO                     54874       MIXTO        NOCHE
# 8       TÉCNICO/ACADÉMICO                     54810       MIXTO       MAÑANA
# 10              ACADÉMICO                     54001       MIXTO     COMPLETA
# ...                   ...                       ...         ...          ...
# 195848  TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 195850          ACADÉMICO                     54001       MIXTO       MAÑANA
# 195852  TÉCNICO/ACADÉMICO                     54405       MIXTO       MAÑANA
# 195854  TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 195855            TÉCNICO                     54800       MIXTO       MAÑANA
#
#        cole_mcpio_ubicacion cole_naturaleza  ...  fami_tienecomputador  \
# 1                    CÚCUTA         OFICIAL  ...                    No
# 5         VILLA DEL ROSARIO         OFICIAL  ...                    No
# 7         VILLA DEL ROSARIO         OFICIAL  ...                    No
# 8                      TIBU         OFICIAL  ...                    Si
# 10                   CUCUTA      NO OFICIAL  ...                    Si
# ...                     ...             ...  ...                   ...
# 195848               CÚCUTA         OFICIAL  ...                    Si
# 195850               CÚCUTA      NO OFICIAL  ...                    No
# 195852           LOS PATIOS         OFICIAL  ...                    No
# 195854               CUCUTA         OFICIAL  ...                    No
# 195855              TEORAMA         OFICIAL  ...                    No
#
#         fami_tieneinternet fami_tienelavadora desemp_ingles punt_ingles  \
# 1                       Si                 Si            A-        32.0
# 5                       No                 No            A-        38.0
# 7                       Si                 No            A-        43.0
# 8                       Si                 Si            A-        47.0
# 10                      Si                 Si            A-        47.0
# ...                    ...                ...           ...         ...
# 195848                  Si                 No            B+        83.0
# 195850                  Si                 Si            A1        52.0
# 195852                  No                 Si            A1        51.0
# 195854                  No                 No            A-        47.0
# 195855                  No                 No            A-        41.0
#
#        punt_matematicas punt_sociales_ciudadanas punt_c_naturales  \
# 1                  45.0                     42.0             42.0
# 5                  21.0                     32.0             29.0
# 7                  28.0                     33.0             36.0
# 8                  39.0                     42.0             49.0
# 10                 44.0                     41.0             44.0
# ...                 ...                      ...              ...
# 195848             79.0                     81.0             72.0
# 195850             45.0                     42.0             55.0
# 195852             50.0                     60.0             55.0
# 195854             33.0                     44.0             40.0
# 195855             47.0                     49.0             49.0
#
#        punt_lectura_critica punt_global
# 1                      49.0       218.0
# 5                      33.0       147.0
# 7                      37.0       171.0
# 8                      49.0       225.0
# 10                     54.0       229.0
# ...                     ...         ...
# 195848                 71.0       382.0
# 195850                 52.0       244.0
# 195852                 50.0       268.0
# 195854                 29.0       187.0
# 195855                 52.0       243.0
#
# [95103 rows x 32 columns]

# %% [markdown]
# #### Ahora revisamos el resto de las columnas, para revisar cual de estas tambien tiene valores en Nan o vacio

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# periodo                            0
# cole_area_ubicacion                0
# cole_bilingue                  13125
# cole_calendario                    0
# cole_caracter                   1606
# cole_cod_mcpio_ubicacion           0
# cole_genero                        0
# cole_jornada                       0
# cole_mcpio_ubicacion               0
# cole_naturaleza                    0
# estu_cod_mcpio_presentacion        0
# estu_cod_reside_mcpio             67
# estu_fechanacimiento               1
# estu_genero                      133
# estu_mcpio_presentacion            0
# estu_mcpio_reside                 67
# fami_cuartoshogar               1304
# fami_educacionmadre             1857
# fami_educacionpadre             1867
# fami_estratovivienda            2076
# fami_personashogar              1316
# fami_tieneautomovil             1357
# fami_tienecomputador            1303
# fami_tieneinternet              1866
# fami_tienelavadora              1286
# desemp_ingles                      6
# punt_ingles                        6
# punt_matematicas                   0
# punt_sociales_ciudadanas           0
# punt_c_naturales                   0
# punt_lectura_critica               0
# punt_global                        0
# dtype: int64

# %% [markdown]
# #### Nos damos cuenta que la columna "Cole_bilingue" tiene muchos null, asi que probamos cuantas filas se eliminarian si quitamos esta columna

# %%
df = data.drop('cole_bilingue', axis=1)
df = df.dropna()
df
# Out:
#         periodo cole_area_ubicacion cole_calendario      cole_caracter  \
# 1         20194              URBANO               A  TÉCNICO/ACADÉMICO
# 5         20194              URBANO               A          ACADÉMICO
# 7         20172              URBANO               A          ACADÉMICO
# 8         20162               RURAL               A  TÉCNICO/ACADÉMICO
# 10        20172              URBANO               A          ACADÉMICO
# ...         ...                 ...             ...                ...
# 195847    20172              URBANO               A  TÉCNICO/ACADÉMICO
# 195848    20194              URBANO               A  TÉCNICO/ACADÉMICO
# 195852    20172              URBANO               A  TÉCNICO/ACADÉMICO
# 195854    20142              URBANO               A  TÉCNICO/ACADÉMICO
# 195855    20142              URBANO               A            TÉCNICO
#
#         cole_cod_mcpio_ubicacion cole_genero cole_jornada  \
# 1                          54001       MIXTO       MAÑANA
# 5                          54874       MIXTO        NOCHE
# 7                          54874       MIXTO        NOCHE
# 8                          54810       MIXTO       MAÑANA
# 10                         54001       MIXTO     COMPLETA
# ...                          ...         ...          ...
# 195847                     54405       MIXTO       MAÑANA
# 195848                     54001       MIXTO       MAÑANA
# 195852                     54405       MIXTO       MAÑANA
# 195854                     54001       MIXTO       MAÑANA
# 195855                     54800       MIXTO       MAÑANA
#
#        cole_mcpio_ubicacion cole_naturaleza  estu_cod_mcpio_presentacion  ...  \
# 1                    CÚCUTA         OFICIAL                        54001  ...
# 5         VILLA DEL ROSARIO         OFICIAL                        54874  ...
# 7         VILLA DEL ROSARIO         OFICIAL                        54874  ...
# 8                      TIBU         OFICIAL                        54810  ...
# 10                   CUCUTA      NO OFICIAL                        54001  ...
# ...                     ...             ...                          ...  ...
# 195847           LOS PATIOS         OFICIAL                        54405  ...
# 195848               CÚCUTA         OFICIAL                        54001  ...
# 195852           LOS PATIOS         OFICIAL                        54405  ...
# 195854               CUCUTA         OFICIAL                        54001  ...
# 195855              TEORAMA         OFICIAL                        54498  ...
#
#         fami_tienecomputador fami_tieneinternet fami_tienelavadora  \
# 1                         No                 Si                 Si
# 5                         No                 No                 No
# 7                         No                 Si                 No
# 8                         Si                 Si                 Si
# 10                        Si                 Si                 Si
# ...                      ...                ...                ...
# 195847                    Si                 Si                 Si
# 195848                    Si                 Si                 No
# 195852                    No                 No                 Si
# 195854                    No                 No                 No
# 195855                    No                 No                 No
#
#        desemp_ingles punt_ingles punt_matematicas punt_sociales_ciudadanas  \
# 1                 A-        32.0             45.0                     42.0
# 5                 A-        38.0             21.0                     32.0
# 7                 A-        43.0             28.0                     33.0
# 8                 A-        47.0             39.0                     42.0
# 10                A-        47.0             44.0                     41.0
# ...              ...         ...              ...                      ...
# 195847            A2        65.0             61.0                     57.0
# 195848            B+        83.0             79.0                     81.0
# 195852            A1        51.0             50.0                     60.0
# 195854            A-        47.0             33.0                     44.0
# 195855            A-        41.0             47.0                     49.0
#
#        punt_c_naturales punt_lectura_critica punt_global
# 1                  42.0                 49.0       218.0
# 5                  29.0                 33.0       147.0
# 7                  36.0                 37.0       171.0
# 8                  49.0                 49.0       225.0
# 10                 44.0                 54.0       229.0
# ...                 ...                  ...         ...
# 195847             58.0                 59.0       296.0
# 195848             72.0                 71.0       382.0
# 195852             55.0                 50.0       268.0
# 195854             40.0                 29.0       187.0
# 195855             49.0                 52.0       243.0
#
# [89938 rows x 31 columns]

# %% [markdown]
# #### Tambien probamos si se dejaran todas las columnas, cuantas filas quedarian al quitar todos los null

# %%
data = data.dropna()
data
# Out:
#         periodo cole_area_ubicacion cole_bilingue cole_calendario  \
# 5         20194              URBANO             N               A
# 7         20172              URBANO             N               A
# 8         20162               RURAL             N               A
# 10        20172              URBANO             N               A
# 17        20142              URBANO             N               A
# ...         ...                 ...           ...             ...
# 195847    20172              URBANO             N               A
# 195848    20194              URBANO             N               A
# 195852    20172              URBANO             N               A
# 195854    20142              URBANO             N               A
# 195855    20142              URBANO             N               A
#
#             cole_caracter  cole_cod_mcpio_ubicacion cole_genero cole_jornada  \
# 5               ACADÉMICO                     54874       MIXTO        NOCHE
# 7               ACADÉMICO                     54874       MIXTO        NOCHE
# 8       TÉCNICO/ACADÉMICO                     54810       MIXTO       MAÑANA
# 10              ACADÉMICO                     54001       MIXTO     COMPLETA
# 17      TÉCNICO/ACADÉMICO                     54003       MIXTO        TARDE
# ...                   ...                       ...         ...          ...
# 195847  TÉCNICO/ACADÉMICO                     54405       MIXTO       MAÑANA
# 195848  TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 195852  TÉCNICO/ACADÉMICO                     54405       MIXTO       MAÑANA
# 195854  TÉCNICO/ACADÉMICO                     54001       MIXTO       MAÑANA
# 195855            TÉCNICO                     54800       MIXTO       MAÑANA
#
#        cole_mcpio_ubicacion cole_naturaleza  ...  fami_tienecomputador  \
# 5         VILLA DEL ROSARIO         OFICIAL  ...                    No
# 7         VILLA DEL ROSARIO         OFICIAL  ...                    No
# 8                      TIBU         OFICIAL  ...                    Si
# 10                   CUCUTA      NO OFICIAL  ...                    Si
# 17                   ABREGO         OFICIAL  ...                    No
# ...                     ...             ...  ...                   ...
# 195847           LOS PATIOS         OFICIAL  ...                    Si
# 195848               CÚCUTA         OFICIAL  ...                    Si
# 195852           LOS PATIOS         OFICIAL  ...                    No
# 195854               CUCUTA         OFICIAL  ...                    No
# 195855              TEORAMA         OFICIAL  ...                    No
#
#         fami_tieneinternet fami_tienelavadora desemp_ingles punt_ingles  \
# 5                       No                 No            A-        38.0
# 7                       Si                 No            A-        43.0
# 8                       Si                 Si            A-        47.0
# 10                      Si                 Si            A-        47.0
# 17                      No                 Si            A-        47.0
# ...                    ...                ...           ...         ...
# 195847                  Si                 Si            A2        65.0
# 195848                  Si                 No            B+        83.0
# 195852                  No                 Si            A1        51.0
# 195854                  No                 No            A-        47.0
# 195855                  No                 No            A-        41.0
#
#        punt_matematicas punt_sociales_ciudadanas punt_c_naturales  \
# 5                  21.0                     32.0             29.0
# 7                  28.0                     33.0             36.0
# 8                  39.0                     42.0             49.0
# 10                 44.0                     41.0             44.0
# 17                 44.0                     41.0             31.0
# ...                 ...                      ...              ...
# 195847             61.0                     57.0             58.0
# 195848             79.0                     81.0             72.0
# 195852             50.0                     60.0             55.0
# 195854             33.0                     44.0             40.0
# 195855             47.0                     49.0             49.0
#
#        punt_lectura_critica punt_global
# 5                      33.0       147.0
# 7                      37.0       171.0
# 8                      49.0       225.0
# 10                     54.0       229.0
# 17                     36.0       193.0
# ...                     ...         ...
# 195847                 59.0       296.0
# 195848                 71.0       382.0
# 195852                 50.0       268.0
# 195854                 29.0       187.0
# 195855                 52.0       243.0
#
# [79001 rows x 32 columns]

# %% [markdown]
# #### Escogemos el dataframe que tiene una columna menos ya que con este podemos tener 10000 datos mas

# %%
data = df
data
# Out:
#         periodo cole_area_ubicacion cole_calendario      cole_caracter  \
# 1         20194              URBANO               A  TÉCNICO/ACADÉMICO
# 5         20194              URBANO               A          ACADÉMICO
# 7         20172              URBANO               A          ACADÉMICO
# 8         20162               RURAL               A  TÉCNICO/ACADÉMICO
# 10        20172              URBANO               A          ACADÉMICO
# ...         ...                 ...             ...                ...
# 195847    20172              URBANO               A  TÉCNICO/ACADÉMICO
# 195848    20194              URBANO               A  TÉCNICO/ACADÉMICO
# 195852    20172              URBANO               A  TÉCNICO/ACADÉMICO
# 195854    20142              URBANO               A  TÉCNICO/ACADÉMICO
# 195855    20142              URBANO               A            TÉCNICO
#
#         cole_cod_mcpio_ubicacion cole_genero cole_jornada  \
# 1                          54001       MIXTO       MAÑANA
# 5                          54874       MIXTO        NOCHE
# 7                          54874       MIXTO        NOCHE
# 8                          54810       MIXTO       MAÑANA
# 10                         54001       MIXTO     COMPLETA
# ...                          ...         ...          ...
# 195847                     54405       MIXTO       MAÑANA
# 195848                     54001       MIXTO       MAÑANA
# 195852                     54405       MIXTO       MAÑANA
# 195854                     54001       MIXTO       MAÑANA
# 195855                     54800       MIXTO       MAÑANA
#
#        cole_mcpio_ubicacion cole_naturaleza  estu_cod_mcpio_presentacion  ...  \
# 1                    CÚCUTA         OFICIAL                        54001  ...
# 5         VILLA DEL ROSARIO         OFICIAL                        54874  ...
# 7         VILLA DEL ROSARIO         OFICIAL                        54874  ...
# 8                      TIBU         OFICIAL                        54810  ...
# 10                   CUCUTA      NO OFICIAL                        54001  ...
# ...                     ...             ...                          ...  ...
# 195847           LOS PATIOS         OFICIAL                        54405  ...
# 195848               CÚCUTA         OFICIAL                        54001  ...
# 195852           LOS PATIOS         OFICIAL                        54405  ...
# 195854               CUCUTA         OFICIAL                        54001  ...
# 195855              TEORAMA         OFICIAL                        54498  ...
#
#         fami_tienecomputador fami_tieneinternet fami_tienelavadora  \
# 1                         No                 Si                 Si
# 5                         No                 No                 No
# 7                         No                 Si                 No
# 8                         Si                 Si                 Si
# 10                        Si                 Si                 Si
# ...                      ...                ...                ...
# 195847                    Si                 Si                 Si
# 195848                    Si                 Si                 No
# 195852                    No                 No                 Si
# 195854                    No                 No                 No
# 195855                    No                 No                 No
#
#        desemp_ingles punt_ingles punt_matematicas punt_sociales_ciudadanas  \
# 1                 A-        32.0             45.0                     42.0
# 5                 A-        38.0             21.0                     32.0
# 7                 A-        43.0             28.0                     33.0
# 8                 A-        47.0             39.0                     42.0
# 10                A-        47.0             44.0                     41.0
# ...              ...         ...              ...                      ...
# 195847            A2        65.0             61.0                     57.0
# 195848            B+        83.0             79.0                     81.0
# 195852            A1        51.0             50.0                     60.0
# 195854            A-        47.0             33.0                     44.0
# 195855            A-        41.0             47.0                     49.0
#
#        punt_c_naturales punt_lectura_critica punt_global
# 1                  42.0                 49.0       218.0
# 5                  29.0                 33.0       147.0
# 7                  36.0                 37.0       171.0
# 8                  49.0                 49.0       225.0
# 10                 44.0                 54.0       229.0
# ...                 ...                  ...         ...
# 195847             58.0                 59.0       296.0
# 195848             72.0                 71.0       382.0
# 195852             55.0                 50.0       268.0
# 195854             40.0                 29.0       187.0
# 195855             49.0                 52.0       243.0
#
# [89938 rows x 31 columns]

# %% [markdown]
# #### Ahora  Revisamos que en nuestro dataframe ya no quede, ningun duplicado o null

# %%
duplicates = len(data[data.duplicated()])
print(f'Numero de duplicados: {duplicates}')
missing_values = data.isnull().sum().sum()
print(f'Numero de valores nullos: {missing_values}')
# Out:
# Numero de duplicados: 0
# Numero de valores nullos: 0

# %% [markdown]
# #### Ahora revisamos cuales columnas nos quedan y cuales queremos sacar

# %%
data.dtypes
# Out:
# periodo                          int64
# cole_area_ubicacion             object
# cole_calendario                 object
# cole_caracter                   object
# cole_cod_mcpio_ubicacion         int64
# cole_genero                     object
# cole_jornada                    object
# cole_mcpio_ubicacion            object
# cole_naturaleza                 object
# estu_cod_mcpio_presentacion      int64
# estu_cod_reside_mcpio          float64
# estu_fechanacimiento            object
# estu_genero                     object
# estu_mcpio_presentacion         object
# estu_mcpio_reside               object
# fami_cuartoshogar               object
# fami_educacionmadre             object
# fami_educacionpadre             object
# fami_estratovivienda            object
# fami_personashogar              object
# fami_tieneautomovil             object
# fami_tienecomputador            object
# fami_tieneinternet              object
# fami_tienelavadora              object
# desemp_ingles                   object
# punt_ingles                    float64
# punt_matematicas               float64
# punt_sociales_ciudadanas       float64
# punt_c_naturales               float64
# punt_lectura_critica           float64
# punt_global                    float64
# dtype: object
